# %% [markdown]
# # Publications in OpenAlex of "Profesores de Cátedra 2023-1" from 2019

# %% [markdown]
# ## UdeA articles in OpenAlex from 2019 and until 10 authors

# %%
import requests
from IPython.display import JSON
import time
import pandas as pd
import unidecode as ud
from fuzzywuzzy import process
import getpass

# %%
def pagination(base_url,count_levels,results_key,page_key,per_page_key,per_page_value=100,sleep=0.1):
    '''
    Pagination for API with url:
    
     `f"{base_url}&{page_key}=1&{per_page_value}=100"`
    
    with the following minimal data scheme:
    ```
     {'level 0 to count key': dict,
         ...
         {'level n to count key': int},
      results_key: list, # with the results
     } 
    
    ```
    OpenAlex example
    ```
     {'meta': 
         {'count': 1223,...},
      'results': [...]
     } 
    ```
    → count_levels=[{'level':0,'to_count_key':'meta'},{'level':1,'to_count_key':'count'}] 
    '''
    per_page_value=per_page_value
    page=1
    r=[]
    j=requests.get(f'{base_url}&{page_key}={page}&{per_page_key}={per_page_value}')
    if j.status_code==200:
        count=j.json()
        for l in set([d.get('level') for d in count_levels]):
            count=count.get( [d.get('to_count_key') for d in count_levels if d.get('level')==l][0]  )

    if isinstance(count,int) and count:
        r = r+j.json().get(results_key) # First page
        npages=count//per_page_value
        if count%per_page_value:
            npages+=1
            
            
    for page in range(2,npages+1):
        print(page,end='\r')
        url=f'{base_url}&{page_key}={page}&{per_page_key}={per_page_value}'
        j=requests.get(url)
        time.sleep(sleep) # Avoid overload the API
        if j.status_code==200:
            r = r+j.json().get(results_key) # First page
    
    return r

# %%
base_url='https://api.openalex.org/works?filter=authorships.institutions.id:I35961687,authors_count:1-10,publication_year:2019-2023'
count_levels=[{'level':0,'to_count_key':'meta'},{'level':1,'to_count_key':'count'}] # data scheme for count in JSON
per_page_key='per-page'
page_key='page'
results_key='results' # Must be at the first level in the JSON output

# %%
r=pagination(base_url,count_levels,results_key,page_key,per_page_key,per_page_value=100,sleep=0.1)
# Out:
# 81

# %%
len(r)
# Out:
# 7933

# %% [markdown]
# ## List of "Profesores de Cátedra 2023-1"

# %%
pc=pd.read_excel('https://docs.google.com/spreadsheets/d/e/2PACX-1vSLsgufZB-CrICillvQufKIFOJ0oILmrSflfud2MH6EoTn5sHsmklRq4N8LIo4SVPFjrWor0aUBSNWA/pub?output=xlsx')

# %% [markdown]
# ### Fix wrong last names

# %%
d=pc[pc['Segundo apellido'].fillna('').str.contains('CARVAJAL')].iloc[0].to_dict()
d['Nombres']=d['Nombres'].replace('DAVID','A')
pa=d['Primer apellido']
d['Primer apellido']=d['Segundo apellido']
d['Segundo apellido']=pa

pc=pd.concat((pc,pd.DataFrame([d]))).reset_index(drop=True)

# %%
d=pc[pc['Nombres'].fillna('').str.contains('ANYERES')].iloc[0].to_dict()
pa=d['Primer apellido']
d['Primer apellido']=d['Segundo apellido']
d['Segundo apellido']=pa

pc=pd.concat((pc,pd.DataFrame([d]))).reset_index(drop=True)

# %% [markdown]
# ### Creates auxiliary lists

# %%
pc['Primer nombre']=pc['Nombres'].str.split().str[0]
pc['Inicial segundo nombre']=pc['Nombres'].str.split().str[1].str[0]

# %%
catedra_short=pc.fillna('').apply(lambda row: ud.unidecode((row['Nombres'].strip().split()[0]+' '+row['Primer apellido'].strip()
                                ).strip().lower()),axis='columns').to_list()

# %%
catedra_initials=pc.fillna('').apply(lambda row: ud.unidecode((  ' '.join([n[0] for n in row['Nombres'].strip().split()])+' '+row['Primer apellido'].strip()+' '+row['Segundo apellido']
                                ).strip().lower()),axis='columns').to_list()

# %%
catedra_name_initial=pc.fillna('').apply(lambda row: ud.unidecode((row['Primer nombre'].strip()+' '+row['Inicial segundo nombre'].strip()+' '+row['Primer apellido'].strip()+' '+row['Segundo apellido']
                                ).strip().lower()),axis='columns').to_list()
catedra_name_initial_partial=pc.fillna('').apply(lambda row: ud.unidecode((row['Primer nombre'].strip()+' '+row['Inicial segundo nombre'].strip()+' '+row['Primer apellido'].strip()
                                ).strip().lower()),axis='columns').to_list()
catedra_name_initial_partial2=pc.fillna('').apply(lambda row: ud.unidecode((row['Primer nombre'].strip()+' '+row['Inicial segundo nombre'].strip()+' '+row['Segundo apellido'].strip()
                                ).strip().lower()),axis='columns').to_list()

# %%
catedra=pc.fillna('').apply(lambda row: ud.unidecode((row['Nombres'].strip()+' '+row['Primer apellido'].strip()+' '+row['Segundo apellido']
                                ).strip().lower()),axis='columns').to_list()

# %%
catedra_first_last_name=pc.fillna('').apply(lambda row: ud.unidecode((row['Primer apellido'].strip()
                                ).strip().lower()),axis='columns').to_list()

# %% [markdown]
# ## Extract authors from the list "Profesores de Cátedra 2023-1"

# %%
inst='I35961687'
for w in r:
    aus_inst=[]
    aus_ids=[]
    ids={}
    for d in w.get('authorships'):
        if d.get('institutions'):
            aus_inst=aus_inst+[d.get('author').get('display_name') for dd in d.get('institutions') if 
                      dd.get('id') and dd.get('id').split('/')[-1]==inst]
            aus_ids=aus_ids+[d.get('author').get('id') for dd in d.get('institutions') if 
                      dd.get('id') and dd.get('id').split('/')[-1]==inst]
            
    if aus_inst:
        aus_inst=[ud.unidecode(s.lower()).replace('-',' ').replace('.','') for s in aus_inst]
        
    ids=dict(zip(aus_inst,aus_ids))
        
    for au in aus_inst:
        #if au=='cristian a carvajal':
        #    raise Exception('ar')        
        if au in catedra: # Full names
            one=[au,100]
            w['institution_authorships']=aus_inst
            w['catedra_authorships']=one[0]
            w['catedra_id']=ids.get(au)
            break
        
        if au in catedra_initials: # Initial names and full last names
            one=[catedra[catedra_initials.index(au)],100]
            w['institution_authorships']=aus_inst
            w['catedra_authorships']=one[0]
            w['catedra_id']=ids.get(au)
            break
        
        if au in catedra_short: #First name and first last name
            one=[catedra[catedra_short.index(au)],100]
            w['institution_authorships']=aus_inst
            w['catedra_authorships']=one[0]
            w['catedra_id']=ids.get(au)
            break
        if au in catedra_name_initial: #First name - second initial and full last names
            one=[catedra[catedra_name_initial.index(au)],100]
            w['institution_authorships']=aus_inst
            w['catedra_authorships']=one[0]
            w['catedra_id']=ids.get(au)
            break
        if au in catedra_name_initial_partial: #First name - second initial and first last name
            one=[catedra[catedra_name_initial_partial.index(au)],100]
            w['institution_authorships']=aus_inst
            w['catedra_authorships']=one[0]
            w['catedra_id']=ids.get(au)
            break
        if au in catedra_name_initial_partial2: #First name - second initial and second last name
            one=[catedra[catedra_name_initial_partial2.index(au)],100]
            w['institution_authorships']=aus_inst
            w['catedra_authorships']=one[0]
            w['catedra_id']=ids.get(au)
            break

            
       
        one=process.extractOne(au,catedra)
        if one and set(au.split()).intersection(one[0].split()[-2:]) and au[0] in [s[0] for s in one[0].split()]:
            if len(au.split()[0])>1:
                if not set(au.split()).intersection(one[0].split()[:-2]):
                    one=[]
            if one and len(au.split())==4 and len(one[0].split())==4: #last names
                if au.split()[-2:]!=one[0].split()[-2:]:
                    one=[]
        else:
            one=[]
        #Quality check
        if one:
            #all initials must corresponds
            if set([s[0] for s in au.split()]).difference([s[0] for s in one[0].split()]):
                one=[]
        if one:
            #Last name must be included
            if catedra_first_last_name[catedra.index(one[0])] not in au.split():
                one=[]
        
        w['institution_authorships']=aus_inst
        if one:
            w['catedra_authorships']=one[0]
            w['catedra_id']=ids.get(au)
            break
        else:
            w['catedra_authorships']=''
            w['catedra_id']=''

        
    #if w['id']=='https://openalex.org/W2940095680':
    #    raise Exception('id')

# %% [markdown]
# ### Filter by [OpenAlex level 0 concepts](https://docs.openalex.org/api-entities/concepts):
# * Physics
# * Computer science
# * Materials science
#
# Exclude level 0 concepts: Medicine and Psychology

# %%
df=pd.DataFrame(r)

# %%
df['concepts_0']=df['concepts'].apply(lambda L: [d.get('display_name') for d in L if d.get('level')==0])

# %%
pd.set_option('display.max_colwidth',500)
pd.set_option('display.max_rows', 100)

# %%
cdf=df[df['catedra_authorships'].apply(len)!=0].reset_index(drop=True)
cdf=cdf[ (cdf.concepts_0.apply(lambda L: 'Physics' in L)) |
         (cdf.concepts_0.apply(lambda L: 'Computer science' in L)) |
         (cdf.concepts_0.apply(lambda L: 'Materials science' in L))
       ].reset_index(drop=True)

cdf=cdf[ ~(  
       (cdf.concepts_0.apply(lambda L: 'Medicine' in L)) |
       (cdf.concepts_0.apply(lambda L: 'Psychology' in L))
      )
       ].reset_index(drop=True)

# %% [markdown]
# ### Total results:

# %%
cdf.shape
# Out:
# (61, 38)

# %%
cdf['Journal']=cdf.locations.apply(lambda L: [d.get('source') for d in L]).str[0].str.get('display_name')

# %%
cdf=cdf[['title','Journal','doi','institution_authorships','publication_date', 
                                                 'catedra_authorships','catedra_id','concepts_0','cited_by_count']
                                           ].sort_values('catedra_authorships').reset_index(drop=True)
cdf
# Out:
#                                                                                                                                                                                                         title  \
# 0                                                                                                                                                            Lepton dark matter portal in the inert Zee model
# 1                                                                                                                                                       Singlet-doublet Dirac dark matter and neutrino masses
# 2                                                                                                                                                                 Inert doublet as multicomponent dark matter
# 3                                                                                                                                                  Type-II two-Higgs-doublet model in noncommutative geometry
# 4                                                                                                                                                   Dirac dark matter, neutrino masses, and dark baryogenesis
# 5                                                                                                                                        Phenomenological consistency of the singlet-triplet scotogenic model
# 6                                                                                                                                         Quantum phase transition and Berry phase in an extended Dicke model
# 7                                                                                                                                 Non-interferometric key recording applied to a joint transform cryptosystem
# 8                                                                                                                                               Orbital decay of short-period gas giants under evolving tides
# 9                                                                                                                                               One-loop Dirac neutrino mass and mixed axion-WIMP dark matter
# 10                                                                                                                                 Singlet fermion dark matter and Dirac neutrinos from Peccei-Quinn symmetry
# 11                                                                                                Estimating the number of clear sky nights using GOES-16 images: a search for astronomical sites in Colombia
# 12                                                                                                                             Neutrino-induced single pion production and the reanalyzed bubble chamber data
# 13                                                                                                                                                       Weak pion-production and the second resonance region
# 14                                                                                                                                                    Superconductivity in monocrystalline YNiSi3 and LuNiSi3
# 15                                            Tidal Coulomb Failure Stresses in the northern Andean intermediate depth seismic clusters: Implications for a possible correlation between tides and seismicity
# 16                                                                                                               Correlation between tides and seismicity in Northwestern South America: The case of Colombia
# 17                                                                           Cation Vacancies in NiFe2O4 During Heat Treatments at High Temperatures: Structural, Morphological and Magnetic Characterization
# 18                                                                                       New method to calculate Mössbauer recoilless f-factors in NiFe2O4. Magnetic, morphological and structural properties
# 19                                                                                                                               Tailoring dual reversal modes by helicity control in ferromagnetic nanotubes
# 20                                                                                                                   Numerical Study on Surface Reconstruction and Roughness of Magnetorheological Elastomers
# 21                                                                                                                      A time-energy delayed-choice interference experiment for the undergraduate laboratory
# 22                                                                          Self-Consistent Schrödinger-Poisson Study of Electronic Properties of GaAs Quantum Well Wires with Various Cross-Sectional Shapes
# 23                            Electronic Transport Properties in GaAs/AlGaAs and InSe/InP Finite Superlattices under the Effect of a Non-Resonant Intense Laser Field and Considering Geometric Modifications
# 24                                                                                                                  Study of Electronic and Transport Properties in Double-Barrier Resonant Tunneling Systems
# 25                                                                                                                                   Self-Consistent Study of GaAs/AlGaAs Quantum Wells with Modulated Doping
# 26                                                         Shallow Donor Impurity States with Excitonic Contribution in GaAs/AlGaAs and CdTe/CdSe Truncated Conical Quantum Dots under Applied Magnetic Field
# 27                                                             Theoretical study of electronic and optical properties in doped quantum structures with Razavy confining potential: effects of external fields
# 28                                                                                                                                      Improved decryption quality with a random reference beam cryptosystem
# 29                                                                                                                                                            Focus-tunable experimental optical cryptosystem
# 30                                                                                                                    Experimental Fresnel and Fourier digital holography using a digital micro-mirror device
# 31                                                                                                                                        High performance compact optical cryptosystem without reference arm
# 32                  Integration of the straightforward and environmentally friendly sol–gel/solvothermal and photodeposition methods as a way to prepare highly photoactive Au/S-TiO2 and Cu/S-TiO2 materials
# 33                                                             Experimental exploration of dynamic phase transitions and associated metamagnetic fluctuations for materials with different Curie temperatures
# 34                                                                   Correlation between structure and magnetic properties in Eu$${_{1 - x}}$$Ho$${_{x}}$$CrO$${_{3}}$$ (x = 0.0, 0.5 and 1.0) orthochromites
# 35                                                                                                             A brief discussion of the magnetocaloric effect in thin films of manganite doped with chromium
# 36                                                                                       Experimental exploration of the vector nature of the dynamic order parameter near dynamic magnetic phase transitions
# 37                                                                                                                                                               Minimal radiative Dirac neutrino mass models
# 38                                                                                                      Situación del acceso abierto en las universidades. Caso y modelo de análisis Universidad de Antioquia
# 39                                                                                                                                         Anomaly-free Abelian gauge symmetries with Dirac scotogenic models
# 40                                                                                                                                                   Dirac neutrino mass generation from a Majorana messenger
# 41                                                                                                                       Hacia un modelo de medición de la ciencia desde el Sur Global: métricas responsables
# 42                                                                                                                       Phenomenology of the Zee model for Dirac neutrinos and general neutrino interactions
# 43                                                                                                             An Open edX Extension for Parallel Programming Assignments with Automatic Configurable Grading
# 44                                                                                                                                    La paleomicrobiología molecular permite dilucidar el origen de la plaga
# 45                                                                             Implementation of a portable EDXRF measurement chain for characterization of metallic objects of cultural interest in Colombia
# 46                                                                                                                     Non-crossing monotone paths and binary trees in edge-ordered complete geometric graphs
# 47                                                                                                                                          SUBSTRUCTURE FORMATION IN TIDAL STREAMS OF GALACTIC MINOR MERGERS
# 48                                                                                                         Simulating the galactic system in interaction AM 2229-735 and the formation of its polar structure
# 49                                                                                            Refractive index and group velocity of electromagnetic modes in a relativistic Fermi gas at finite temperatures
# 50                                                                                                                  The impact of tidal friction evolution on the orbital decay of ultra-short-period planets
# 51                                                                                                                                            Can we predict the impact conditions of metre-sized meteoroids?
# 52                                                                                                                                                   Can close-in giant exoplanets preserve detectable moons?
# 53                                                                                                                             Ploonets: formation, evolution, and detectability of tidally detached exomoons
# 54                                                                                                                                                     High order accelerating method for quadratic sequences
# 55  Formation of Au@Ag Bimetallic Nanoparticles via Ion Implantation and Its Effects on Boosting the Near-Infrared Emission of Er<sup>3+</sup> Ions in Germanate Glass for Applications in Optical Amplifiers
# 56                                                                                                                                             Empirical Potential for Structural Modeling of Znfe2o4 Systems
# 57                                                                                                                   Experimental model for the description of the behaviour of a 9-mm projectile at a target
# 58                                                                                                                                          Hysteresis characterization of an electrically focus-tunable lens
# 59                                                                                                                           Optimization of the light sword optical element (LSOE) for presbyopia correction
# 60                                                                                                                                Optical characterization of electro-optics lenses for researching in optics
#
#                                                                        Journal  \
# 0                                    International Journal of Modern Physics A
# 1                                                              Physical review
# 2                                                            Nuclear Physics B
# 3                                                            Nuclear Physics B
# 4                                                            Physical Review D
# 5                                               Journal of High Energy Physics
# 6                                                  European Physical Journal D
# 7                                                               Optics Letters
# 8                            Monthly Notices of the Royal Astronomical Society
# 9                                                              Physical review
# 10                                                             Physical review
# 11                                     International Journal of Remote Sensing
# 12                                                           Physical Review D
# 13                                                           Physical Review D
# 14                                                             Physical review
# 15                                                              Tectonophysics
# 16                                    Journal of South American Earth Sciences
# 17                      Materials Research-ibero-american Journal of Materials
# 18                                 Journal of Magnetism and Magnetic Materials
# 19                                                             Physical review
# 20                                                         Computation (Basel)
# 21                                                 European Journal of Physics
# 22                                                               Nanomaterials
# 23                                 International Journal of Molecular Sciences
# 24                                                               Nanomaterials
# 25                                                               Nanomaterials
# 26                                                               Nanomaterials
# 27                                        Journal of Computational Electronics
# 28                                            Optics and Lasers in Engineering
# 29                                                 Optics and Laser Technology
# 30                                                           Journal of Optics
# 31                                                           Journal of Optics
# 32                                            Journal of Nanoparticle Research
# 33                                                             Physical review
# 34                      Journal of Materials Science: Materials in Electronics
# 35                                                          Journal of physics
# 36                                                             Physical review
# 37                                                             Physical review
# 38                                                    Palabra Clave [La Plata]
# 39                                                             Physical review
# 40                                                             Physical review
# 41                                                    Palabra Clave [La Plata]
# 42                                                           Physical Review D
# 43                        International Journal of Engineering Pedagogy (iJEP)
# 44  Revista de la Academia Colombiana de Ciencias Exactas, Físicas y Naturales
# 45                                                          Journal of physics
# 46                                                  Acta Mathematica Hungarica
# 47                                Revista Mexicana De Astronomia Y Astrofisica
# 48                           Monthly Notices of the Royal Astronomical Society
# 48                https://doi.org/10.1093/mnras/stz2943
# 49              https://doi.org/10.1364/josab.37.000211
# 50               https://doi.org/10.1093/mnras/stab1081
# 51                https://doi.org/10.1093/mnrasl/slz060
# 52                https://doi.org/10.1093/mnras/stz3548
# 53                https://doi.org/10.1093/mnras/stz2110
# 54           https://doi.org/10.1007/s40324-023-00327-3
# 55             https://doi.org/10.1021/acs.jpcc.2c07998
# 56                 https://doi.org/10.2139/ssrn.4027394
# 57        https://doi.org/10.1080/20961790.2019.1697078
# 58             https://doi.org/10.1117/1.oe.59.4.044103
# 59                                                 None
# 60                   https://doi.org/10.1117/12.2568577
#
#                                                                                                                                                                                                              institution_authorships  \
# 0                                                                                                                                                                                [alexandra gaviria, robinson longas, andres rivera]
# 1                                                                                                                                                                                                    [diego restrepo, andres rivera]
# 2                                                                                                                                                                                                                    [andres rivera]
# 3                                                                                                                                                                                    [jimenez, fredy, diego restrepo, andres rivera]
# 4                                                                                                                                                                                                    [diego restrepo, andres rivera]
# 5                                                                                                                                                                                                    [diego restrepo, andres rivera]
# 6                                                                                                                                                                                         [camilo a estrada guerra, j mahecha gomez]
# 7                                                                                                                                                              [carlos vargas castrillon, alejandro velez zea, john barrera ramirez]
# 8                                                                                                                                                                                 [jaime a alvarado montes, carolina garcia carmona]
# 9                                                                                                                                                                                                [cristian a carvajal, oscar zapata]
# 10                                                                                                                                                             [cristian a carvajal, robinson longas, oscar rodriguez, oscar zapata]
# 11                                                                                                                                     [d arbelaez cardona, e silva villa, j galvez, j alejandro martinez, pablo a cuartas restrepo]
# 12                                                                                                                                                                                        [d f tamayo agudelo, d e jaramillo arango]
# 13                                                                                                                                                                                        [d f tamayo agudelo, d e jaramillo arango]
# 14                                                                                                                                                                               [deisy aristizabal giraldo, jorge m osorio guillen]
# 15                                                                                                                                                                                               [gloria a moncayo, jorge i zuluaga]
# 16                                                                                                                                                                                               [gloria a moncayo, jorge i zuluaga]
# 17                                                                                                                                              [harrison salazar tamayo, karen edilma garcia tellez, cesar augusto barrero meneses]
# 18                                                                                                                                                                                        [h salazar tamayo, ke garcia, c a barrero]
# 19                                                                                                                                                                                                    [h d salinas, johans restrepo]
# 20                                                                                                                                                                                                    [johans restrepo, h d salinas]
# 21                                                                                                                                                                                            [jhonny castrillon, boris a rodriguez]
# 22                                                                                                                                                                       [john a gil corrales, ja vinasco, alvaro morales, ca duque]
# 23                                                                                                                                                                                   [john a gil corrales, alvaro morales, ca duque]
# 24                                                                                                                                                                       [john a gil corrales, ja vinasco, alvaro morales, ca duque]
# 25                                                                                                                                                                                 [john a gil corrales, alvaro l morales, ca duque]
# 26                                                                                                                                                                                   [john a gil corrales, alvaro morales, ca duque]
# 27                                                                                                                                                         [john a gil corrales, alvaro morales, vn tulupenko, ja vinasco, ca duque]
# 28                                                                                                                                           [alexis jaramillo osorio, john jairo ramirez, santiago montoya, alejandro mira agudelo]
# 29                                                                                                  [john alexis jaramillo osorio, walter torres sepulveda, alejandro velez zea, alejandro mira agudelo, john fredy barrera ramirez]
# 4        2022-09-16        andres felipe rivera romero
# 5        2020-04-01        andres felipe rivera romero
# 6        2020-10-01      camilo alberto estrada guerra
# 7        2022-12-21    carlos andres vargas castrillon
# 8        2019-07-01            carolina garcia carmona
# 9        2019-04-09           cristian a carvajal ruiz
# 10       2022-01-04           cristian a carvajal ruiz
# 11       2020-04-12            daniel arbelaez cardona
# 12       2022-08-02        david felipe tamayo agudelo
# 13       2022-02-22        david felipe tamayo agudelo
# 14       2019-06-11  deisy viviana aristizabal giraldo
# 15       2019-07-05     gloria alexandra moncayo gamez
# 16       2019-01-01     gloria alexandra moncayo gamez
# 17       2019-12-20     harrison osfrey salazar tamayo
# 18       2019-02-01     harrison osfrey salazar tamayo
# 19       2020-02-13       hernan david salinas jimenez
# 20       2023-02-27       hernan david salinas jimenez
# 21       2019-08-19  jhonny alexander castrillon perez
# 22       2021-05-05        john alexander gil corrales
# 23       2022-05-05        john alexander gil corrales
# 24       2022-05-17        john alexander gil corrales
# 25       2023-03-01        john alexander gil corrales
# 26       2021-10-25        john alexander gil corrales
# 27       2022-03-07        john alexander gil corrales
# 28       2019-01-01       john alexis jaramillo osorio
# 29       2022-04-01       john alexis jaramillo osorio
# 30       2021-01-08       john alexis jaramillo osorio
# 31       2020-01-27       john alexis jaramillo osorio
# 32       2022-12-01          juan marcos marin ramirez
# 33       2020-08-20          juan marcos marin ramirez
# 34       2021-05-01          juan marcos marin ramirez
# 35       2019-06-01          juan marcos marin ramirez
# 36       2020-09-28          juan marcos marin ramirez
# 37       2019-04-09       julian andres calle mosquera
# 38       2019-10-28       julian andres calle mosquera
# 39       2021-05-27       julian andres calle mosquera
# 40       2020-02-06       julian andres calle mosquera
# 41       2019-04-30       julian andres calle mosquera
# 42       2021-07-28       julian andres calle mosquera
# 43       2021-07-09         luis felipe ramirez garcia
# 44       2022-08-11         luis felipe ramirez garcia
# 45       2019-06-01         luis felipe ramirez garcia
# 46       2021-10-01          luis fernando duque gomez
# 47       2019-10-01       luis fernando quiroga pelaez
# 48       2019-10-24       luis fernando quiroga pelaez
# 49       2020-02-01       luis miguel hincapie zuluaga
# 50       2021-07-23   mario alexander sucerquia areiza
# 51       2019-06-11   mario alexander sucerquia areiza
# 52       2020-03-01   mario alexander sucerquia areiza
# 53       2019-10-21   mario alexander sucerquia areiza
# 54       2023-04-25   oscar antonio restrepo gutierrez
# 55       2022-12-28   oscar antonio restrepo gutierrez
# 56       2022-01-01   oscar antonio restrepo gutierrez
# 57       2021-01-02     patricia de jesus morales vega
# 58       2020-04-08      walter arley torres sepulveda
# 59       2019-07-22      walter arley torres sepulveda
# 60       2020-08-20      walter arley torres sepulveda
#
#                           catedra_id  \
# 0   https://openalex.org/A2890818477
# 1   https://openalex.org/A4353121559
# 2   https://openalex.org/A4353121559
# 3   https://openalex.org/A2485835366
# 4   https://openalex.org/A4353121559
# 5   https://openalex.org/A4353121559
# 6   https://openalex.org/A3089404635
# 7   https://openalex.org/A4316243382
# 8   https://openalex.org/A2943153277
# 25                                                                    [Materials science, Physics]
# 26                                                                          [Physics, Mathematics]
# 27                                                                                       [Physics]
# 28                                                                     [Computer science, Physics]
# 29                                                                     [Computer science, Physics]
# 30                                                  [Computer science, Materials science, Physics]
# 31                                                                     [Computer science, Physics]
# 32                                   [Materials science, Chemistry, Physics, Engineering, Biology]
# 33                                                                    [Materials science, Physics]
# 34                                                         [Materials science, Chemistry, Physics]
# 35                                                                    [Materials science, Physics]
# 36                                                                            [Physics, Economics]
# 37                                                                          [Physics, Mathematics]
# 38                           [Political science, Computer science, Philosophy, Physics, Economics]
# 39                                                                              [Physics, History]
# 40                                                                                       [Physics]
# 41  [Political science, Sociology, Computer science, Philosophy, Geography, Business, Mathematics]
# 42                                                                  [Physics, Philosophy, History]
# 43                                                                 [Computer science, Engineering]
# 44                                                                                  [Physics, Art]
# 45       [Computer science, Materials science, Physics, Chemistry, Environmental science, History]
# 46                                                        [Mathematics, Physics, Computer science]
# 47                                                        [Physics, Computer science, Engineering]
# 48                                                                                       [Physics]
# 49                                                                          [Physics, Engineering]
# 50                                                                                       [Physics]
# 51                                     [Environmental science, Computer science, Physics, Geology]
# 52                                                                    [Physics, Political science]
# 53                                                                                       [Physics]
# 54                                    [Mathematics, Computer science, Physics, Economics, Biology]
# 55                                                                  [Materials science, Chemistry]
# 56                                                                              [Computer science]
# 57                                                                              [Physics, Geology]
# 58                                                  [Computer science, Materials science, Physics]
# 59                               [Materials science, Computer science, Physics, Political science]
# 60                                                [Computer science, Physics, Philosophy, Biology]
#
#     cited_by_count
# 0                0
# 1               16
# 2                9
# 3                0
# 4                0
# 5                7
# 6                2
# 7                0
# 8                7
# 9               19
# 10               3
# 11               0
# 12               0
# 13               1
# 14               5
# 15               1
# 16               4
# 17               7
# 18              22
# 19               5
# 20               0
# 21               5
# 22               5
# 23               0
# 24               1
# 25               0
# 26               6
# 27               4
# 28               7
# 29               2
# 30               5
# 31               7
# 32               0
# 33              16
# 34               0
# 35               0
# 36               8
# 37              31
# 38               1
# 39               7
# 40              12
# 41               2
# 42               3
# 43               0
# 44               0
# 45               0
# 46               1
# 47               0
# 48               0
# 49               1
# 50               5
# 51               2
# 52               9
# 53              17
# 54               0
# 55               0
# 56               0
# 57               0
# 58               4
# 59               0
# 60               1

# %%
cdf.to_excel('publicaciones_catedra.xlsx',index=False)

# %%
j=requests.get('http://apis.colav.co/openscienti/cvlac')

# %%
df=pd.DataFrame( j.json()['scrapped_data'] )

# %%
df[df['Nombre'].str.lower().apply(ud.unidecode).str.contains('oscar antonio restrepo gutierrez')].iloc[0].dropna().get('url')
# Out:
# 'https://scienti.minciencias.gov.co/cvlac/visualizador/generarCurriculoCv.do?cod_rh=0000199800'

# %%
apikey=getpass.getpass()
# Out:
#  ········

# %%
j=requests.get(f'http://apis.colav.co/siiu/project?apikey={apikey}&participant_name=andres+felipe+rivera+romero')

# %%
j.json()[0].get('CODIGO')
# Out:
# '2018-22812'

# %%
41280/316300
# Out:
# 0.1305090104331331
