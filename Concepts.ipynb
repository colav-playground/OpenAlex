# %% [markdown]
# https://docs.google.com/spreadsheets/d/1LBFHjPt4rj_9r0t0TTAlT68NwOtNH8Z21lBMsJDMoZg/edit?usp=sharing

# %%
import pandas as pd

# %%
df=pd.read_excel('https://docs.google.com/spreadsheets/d/e/2PACX-1vT9JrvUwanM-z-hCZ1SSaxRx2wfzLV3RVvm5BJaf8TABBmpIwKt7iYt1sVLbImVevh9YNaZK9Y7sfI9/pub?output=xlsx')

# %%
df.shape
# Out:
# (65026, 7)

# %%
df[df.parent_display_names=='Physics']
# Out:
#                          openalex_id                display_name  \
# 23     https://openalex.org/c3079626     Quantum electrodynamics
# 24    https://openalex.org/c46141821  Nuclear magnetic resonance
# 32   https://openalex.org/c121864883         Statistical physics
# 44    https://openalex.org/c33332235         Theoretical physics
# 71    https://openalex.org/c97355855              Thermodynamics
# 72   https://openalex.org/c185544564             Nuclear physics
# 88   https://openalex.org/c120665830                      Optics
# 129   https://openalex.org/c24890656                   Acoustics
# 151    https://openalex.org/c1276947                   Astronomy
# 160   https://openalex.org/c30475298       Computational physics
# 199  https://openalex.org/c184779094              Atomic physics
# 214   https://openalex.org/c57879066                   Mechanics
# 225   https://openalex.org/c62520636           Quantum mechanics
# 244   https://openalex.org/c74650414         Classical mechanics
# 249   https://openalex.org/c44870925                Astrophysics
# 275   https://openalex.org/c26873012    Condensed matter physics
# 299  https://openalex.org/c109214941            Particle physics
#
#                 normalized_name  level                            wikidata_id  \
# 23      quantum electrodynamics      1  https://www.wikidata.org/wiki/Q234881
# 24   nuclear magnetic resonance      1  https://www.wikidata.org/wiki/Q209402
# 32          statistical physics      1  https://www.wikidata.org/wiki/Q677916
# 44          theoretical physics      1   https://www.wikidata.org/wiki/Q18362
# 71               thermodynamics      1   https://www.wikidata.org/wiki/Q11473
# 72              nuclear physics      1   https://www.wikidata.org/wiki/Q81197
# 88                       optics      1   https://www.wikidata.org/wiki/Q14620
# 129                   acoustics      1   https://www.wikidata.org/wiki/Q82811
# 151                   astronomy      1     https://www.wikidata.org/wiki/Q333
# 160       computational physics      1  https://www.wikidata.org/wiki/Q909554
# 199              atomic physics      1   https://www.wikidata.org/wiki/Q26383
# 214                   mechanics      1   https://www.wikidata.org/wiki/Q41217
# 225           quantum mechanics      1     https://www.wikidata.org/wiki/Q944
# 244         classical mechanics      1   https://www.wikidata.org/wiki/Q11397
# 249                astrophysics      1   https://www.wikidata.org/wiki/Q37547
# 275    condensed matter physics      1  https://www.wikidata.org/wiki/Q214781
# 299            particle physics      1   https://www.wikidata.org/wiki/Q18334
#
#     parent_display_names                       parent_ids
# 23               Physics  https://openalex.org/C121332964
# 24               Physics  https://openalex.org/C121332964
# 32               Physics  https://openalex.org/C121332964
# 44               Physics  https://openalex.org/C121332964
# 71               Physics  https://openalex.org/C121332964
# 72               Physics  https://openalex.org/C121332964
# 88               Physics  https://openalex.org/C121332964
# 129              Physics  https://openalex.org/C121332964
# 151              Physics  https://openalex.org/C121332964
# 160              Physics  https://openalex.org/C121332964
# 199              Physics  https://openalex.org/C121332964
# 214              Physics  https://openalex.org/C121332964
# 225              Physics  https://openalex.org/C121332964
# 43533                           Agricultural land
# 43534                           Urban agriculture
# 50066                      Agricultural geography
# 53022                      Agricultural marketing
# 56825                   Agricultural soil science
# 61869                  Good agricultural practice
#
#                                   normalized_name  level  \
# 103                      agricultural engineering      1
# 171                        agricultural economics      1
# 214                          agricultural science      1
# 2693                         tropical agriculture      2
# 11564                          agricultural waste      2
# 11819                                   hydrology      2
# 18241                           agricultural pest      2
# 18409                                 agriculture      2
# 21141                                     terrace      2
# 21967                  agricultural communication      3
# 22920                agricultural diversification      3
# 23574                    agricultural development      3
# 23578                      ecological agriculture      3
# 24141                   agricultural productivity      3
# 25229                         chinese agriculture      3
# 25379                      agricultural pollution      3
# 27823                     agricultural management      3
# 28759  sustainable agriculture innovation network      3
# 28951                   agricultural biodiversity      3
# 29029                     subsistence agriculture      3
# 29435                    agreement on agriculture      3
# 33163                     sustainable agriculture      3
# 36748                      agricultural education      3
# 37343         environmental impact of agriculture      3
# 38051                          animal agriculture      3
# 38569                      agricultural extension      3
# 38678                  agricultural biotechnology      3
# 38811                        agricultural economy      3
# 38984                     agricultural revolution      3
# 39207                  common agricultural policy      3
# 39365                         agricultural policy      3
# 39579                       irrigated agriculture      3
# 39707                      agricultural machinery      3
# 39843                    conservation agriculture      3
# 40524                       precision agriculture      3
# 41294             agricultural experiment station      3
# 41499                         rainfed agriculture      3
# 42671                                     priming      3
# 43533                           agricultural land      3
# 43534                           urban agriculture      3
# 50066                      agricultural geography      4
# 53022                      agricultural marketing      4
# 56825                   agricultural soil science      5
# 61869                  good agricultural practice      5
#
#                                    wikidata_id  \
# 103      https://www.wikidata.org/wiki/Q194118
# 171      https://www.wikidata.org/wiki/Q396340
# 214     https://www.wikidata.org/wiki/Q3606845
# 2693   https://www.wikidata.org/wiki/Q13106250
# 11564   https://www.wikidata.org/wiki/Q5603620
# 11819   https://www.wikidata.org/wiki/Q2883300
# 18241    https://www.wikidata.org/wiki/Q219174
# 18409     https://www.wikidata.org/wiki/Q11451
# 21141    https://www.wikidata.org/wiki/Q838625
# 21967   https://www.wikidata.org/wiki/Q4693953
# 22920   https://www.wikidata.org/wiki/Q4693955
# 23574  https://www.wikidata.org/wiki/Q55603353
# 23578   https://www.wikidata.org/wiki/Q2751054
# 24141   https://www.wikidata.org/wiki/Q3816336
# 25229   https://www.wikidata.org/wiki/Q2827190
# 25379   https://www.wikidata.org/wiki/Q4693969
# 27823   https://www.wikidata.org/wiki/Q3606845
# 28759   https://www.wikidata.org/wiki/Q7649563
# 28951    https://www.wikidata.org/wiki/Q397284
# 29029   https://www.wikidata.org/wiki/Q2787508
# 29435   https://www.wikidata.org/wiki/Q2822829
# 33163   https://www.wikidata.org/wiki/Q2751054
# 36748   https://www.wikidata.org/wiki/Q3345348
# 37343   https://www.wikidata.org/wiki/Q5381236
# 38051     https://www.wikidata.org/wiki/Q80962
# 38569   https://www.wikidata.org/wiki/Q4693964
# 38678  https://www.wikidata.org/wiki/Q19595794
# 38811    https://www.wikidata.org/wiki/Q396340
# 38984   https://www.wikidata.org/wiki/Q1176512
# 39207    https://www.wikidata.org/wiki/Q220687
# 38569                    https://openalex.org/C118518473
# 38678                    https://openalex.org/C118518473
# 38811                    https://openalex.org/C118518473
# 38984                    https://openalex.org/C118518473
# 39207  https://openalex.org/C118518473, https://opena...
# 39365                    https://openalex.org/C118518473
# 39579  https://openalex.org/C118518473, https://opena...
# 39707                    https://openalex.org/C118518473
# 39843                    https://openalex.org/C118518473
# 40524                    https://openalex.org/C118518473
# 41294                    https://openalex.org/C118518473
# 41499  https://openalex.org/C118518473, https://opena...
# 42671  https://openalex.org/C100701293, https://opena...
# 43533  https://openalex.org/C118518473, https://opena...
# 43534                    https://openalex.org/C118518473
# 50066  https://openalex.org/C186868789, https://opena...
# 53022                     https://openalex.org/C54649085
# 56825  https://openalex.org/C116370137, https://opena...
# 61869                     https://openalex.org/C74893574

# %% [markdown]
# ## UdeA articles from 2019 with level 0 concept: Physics and until 10 authors

# %%
import requests
from IPython.display import JSON
import time

# %%
url='https://api.openalex.org/works?filter=authorships.institutions.id:I35961687,concepts.id:C121332964,authors_count:1-10,publication_year:2019-2023&per-page=100&page=2'
j=requests.get(url)

# %%
r=j.json()

# %%
JSON(r)

# %%
r.get('meta').get('count')
# Out:
# 1245

# %%
def pagination(base_url,count_levels,results_key,page_key,per_page_key,per_page_value=100,sleep=0.1):
    '''
    Pagination for API with url:
    
     `f"{base_url}&{page_key}=1&{per_page_value}=100"`
    
    with the following minimal data scheme:
    ```
     {'level 0 to count key': dict,
         ...
         {'level n to count key': int},
      results_key: list, # with the results
     } 
    
    ```
    OpenAlex example
    ```
     {'meta': 
         {'count': 1223,...},
      'results': [...]
     } 
    ```
    → count_levels=[{'level':0,'to_count_key':'meta'},{'level':1,'to_count_key':'count'}] 
    '''
    per_page_value=per_page_value
    page=1
    r=[]
    j=requests.get(f'{base_url}&{page_key}={page}&{per_page_key}={per_page_value}')
    if j.status_code==200:
        count=j.json()
        for l in set([d.get('level') for d in count_levels]):
            count=count.get( [d.get('to_count_key') for d in count_levels if d.get('level')==l][0]  )

    if isinstance(count,int) and count:
        r = r+j.json().get(results_key) # First page
        npages=count//per_page_value
        if count%per_page_value:
            npages+=1
            
            
    for page in range(2,npages+1):
        print(page,end='\r')
        url=f'{base_url}&{page_key}={page}&{per_page_key}={per_page_value}'
        j=requests.get(url)
        time.sleep(sleep) # Avoid overload the API
        if j.status_code==200:
            r = r+j.json().get(results_key) # First page
    
    return r

# %%
#base_url='https://api.openalex.org/works?filter=authorships.institutions.id:I35961687,concepts.id:C121332964,authors_count:1-10,publication_year:2019-2023'
base_url='https://api.openalex.org/works?filter=authorships.institutions.id:I35961687,authors_count:1-10,publication_year:2019-2023'

count_levels=[{'level':0,'to_count_key':'meta'},{'level':1,'to_count_key':'count'}] # data scheme for count in JSON
per_page_key='per-page'
page_key='page'
results_key='results' # Must be at the first level in the JSON output

# %%
r=pagination(base_url,count_levels,results_key,page_key,per_page_key,per_page_value=100,sleep=0.1)
# Out:
# 81

# %%
import pandas as pd

# %%
len(r)
# Out:
# 8030

# %%
len(set([d.get('id') for d in r]))
# Out:
# 8018

# %%
import unidecode as ud
from fuzzywuzzy import process
import pandas as pd

# %%
pc=pd.read_excel('https://docs.google.com/spreadsheets/d/e/2PACX-1vSLsgufZB-CrICillvQufKIFOJ0oILmrSflfud2MH6EoTn5sHsmklRq4N8LIo4SVPFjrWor0aUBSNWA/pub?output=xlsx')

# %%
d=pc[pc['Segundo apellido'].fillna('').str.contains('CARVAJAL')].iloc[0].to_dict()
d['Nombres']=d['Nombres'].replace('DAVID','A')
pc=pd.concat((pc,pd.DataFrame([d]))).reset_index(drop=True)

# %%
pc.columns
# Out:
# Index(['Año', 'Semestre', 'Primer apellido', 'Segundo apellido', 'Nombres'], dtype='object')

# %%
pc['Primer nombre']=pc['Nombres'].str.split().str[0]
pc['Inicial segundo nombre']=pc['Nombres'].str.split().str[1].str[0]

# %%
pc[50:]
# Out:
#        Año Semestre  Primer apellido Segundo apellido              Nombres  \
# 50   2023        1        JARAMILLO          GALLEGO      JOHNY ALEXANDER
# 51   2023        1          LONDOÑO          LONDOÑO              NATALIA
# 52   2023        1           LONGAS           BEDOYA             ROBINSON
# 53   2023        1            LOPEZ           PATIÑO      EDUIN ALEXANDER
# 54   2023        1            MARIN          RAMIREZ          JUAN MARCOS
# 55   2023        1            MARIN          ACEVEDO          PAUL DANIEL
# 56   2023        1         MARTINEZ          CASTAÑO      SEBASTIAN DAVID
# 57   2023        1          MENESES           SIERRA        KAREN YULIETH
# 58   2023        1          MONCAYO            GAMEZ     GLORIA ALEXANDRA
# 59   2023        1          MORALES            MARIN   JENNYFER ALEXANDRA
# 60   2023        1          MORALES             VEGA    PATRICIA DE JESUS
# 61   2023        1          NARANJO            URIBE               ANDRES
# 62   2023        1          NAVARRO            SERNA       VICTOR GABRIEL
# 63   2023        1           NOREÑA          BLANDON         DAVID ANDRES
# 64   2023        1           OCAMPO            HENAO               DANIEL
# 65   2023        1            OCHOA            ROJAS         ANDRES ARBEY
# 66   2023        1           OSORIO           PELAEZ          FABIO ONIER
# 67   2023        1          PALACIO         CARDENAS    GUILLERMO ALBERTO
# 68   2023        1             PINO          QUICENO               JULIAN
# 69   2023        1          QUICENO            RAMOS         LUCAS HERNAN
# 70   2023        1         QUINTERO            GOMEZ              XIOMARA
# 71   2023        1         QUINTERO           MORENO              ESTEBAN
# 72   2023        1          QUIROGA           PELAEZ        LUIS FERNANDO
# 73   2023        1           QUIRÓS         ARROYAVE            JUAN JOSÉ
# 74   2023        1          RAMIREZ          QUICENO        LEIDY MARIANA
# 75   2023        1          RAMIREZ           GARCIA          LUIS FELIPE
# 76   2023        1         RESTREPO        GUTIERREZ        OSCAR ANTONIO
# 77   2023        1             RIOS            PEREZ      DIEGO ALEJANDRO
# 78   2023        1           RIVERA           ROMERO        ANDRES FELIPE
# 79   2023        1        RODRIGUEZ        CIFUENTES         OSCAR ANDRES
# 80   2023        1             RUIZ         CARVAJAL       CRISTIAN DAVID
# 81   2023        1          SALAZAR           TAMAYO      HARRISON OSFREY
# 82   2023        1          SALAZAR           IMPATA        DIEGO ARMANDO
# 83   2023        1          SALINAS          JIMENEZ         HERNAN DAVID
# 84   2023        1            SMITH         ARBELAEZ     ALEJANDRO JAVIER
# 85   2023        1           SUAREZ          UBARNES           LUIS DAVID
# 86   2023        1           SUAREZ           ROLDAN      DAVID ALEJANDRO
# 87   2023        1        SUCERQUIA           AREIZA      MARIO ALEXANDER
# 88   2023        1          TABORDA             TORO      BRALLAN ORLANDO
# 89   2023        1           TAMAYO          AGUDELO         DAVID FELIPE
# 90   2023        1           TORRES        SEPULVEDA         WALTER ARLEY
# 91   2023        1           TREJOS         GONZALEZ              SORAYDA
# 92   2023        1           UCHIMA         QUINTERO       JUAN SEBASTIAN
# 93   2023        1         VALENCIA           BALVIN               CAMILO
# 94   2023        1           VARGAS       CASTRILLON        CARLOS ANDRES
# 95   2023        1          VASQUEZ         BETANCUR          JUAN CARLOS
# 96   2023        1            VELEZ          SANCHEZ                MATEO
# 97   2023        1            VELEZ            PARDO         JAIME ARTURO
# 98   2023        1            VELEZ             CANO         OSCAR ANDRES
# 99   2023        1            VILLA          DURANGO     MONICA ALEJANDRA
# 100  2023        1         VILLEGAS          GIRALDO        JOSE HUMBERTO
# 101  2023        1   VON DER PAHLEN               NaN    FEDERICO IGNACIO
# 102  2023        1            YEPES           TAMAYO         JUAN ALBERTO
# 103  2023        1             RUIZ         CARVAJAL           CRISTIAN A
#
#     Primer nombre Inicial segundo nombre
# 50          JOHNY                      A
# 51        NATALIA                    NaN
# 52       ROBINSON                    NaN
# 53          EDUIN                      A
# 54           JUAN                      M
# 55           PAUL                      D
# 56      SEBASTIAN                      D
# 57          KAREN                      Y
# 58         GLORIA                      A
# 59       JENNYFER                      A
# 60       PATRICIA                      D
# 61         ANDRES                    NaN
# 62         VICTOR                      G
# 63          DAVID                      A
# 64         DANIEL                    NaN
# 65         ANDRES                      A
# 66          FABIO                      O
# 67      GUILLERMO                      A
# 68         JULIAN                    NaN
# 69          LUCAS                      H
# 70        XIOMARA                    NaN
# 71        ESTEBAN                    NaN
# 72           LUIS                      F
# 73           JUAN                      J
# 74          LEIDY                      M
# 75           LUIS                      F
# 76          OSCAR                      A
# 77          DIEGO                      A
# 78         ANDRES                      F
# 79          OSCAR                      A
# 80       CRISTIAN                      D
# 81       HARRISON                      O
# 82          DIEGO                      A
# 83         HERNAN                      D
# 84      ALEJANDRO                      J
# 85           LUIS                      D
# 86          DAVID                      A
# 87          MARIO                      A
# 88        BRALLAN                      O
# 89          DAVID                      F
# 90         WALTER                      A
# 91        SORAYDA                    NaN
# 92           JUAN                      S
# 93         CAMILO                    NaN
# 94         CARLOS                      A
# 95           JUAN                      C
# 96          MATEO                    NaN
# 97          JAIME                      A
# 98          OSCAR                      A
# 99         MONICA                      A
# 100          JOSE                      H
# 101      FEDERICO                      I
# 102          JUAN                      A
# 103      CRISTIAN                      A

# %%
catedra_short=pc.fillna('').apply(lambda row: ud.unidecode((row['Nombres'].strip().split()[0]+' '+row['Primer apellido'].strip()
                                ).strip().lower()),axis='columns').to_list()

# %%
catedra_initials=pc.fillna('').apply(lambda row: ud.unidecode((  ' '.join([n[0] for n in row['Nombres'].strip().split()])+' '+row['Primer apellido'].strip()+' '+row['Segundo apellido']
                                ).strip().lower()),axis='columns').to_list()

# %%
catedra_name_initial=pc.fillna('').apply(lambda row: ud.unidecode((row['Primer nombre'].strip()+' '+row['Inicial segundo nombre'].strip()+' '+row['Primer apellido'].strip()+' '+row['Segundo apellido']
                                ).strip().lower()),axis='columns').to_list()
catedra_name_initial_partial=pc.fillna('').apply(lambda row: ud.unidecode((row['Primer nombre'].strip()+' '+row['Inicial segundo nombre'].strip()+' '+row['Primer apellido'].strip()
                                ).strip().lower()),axis='columns').to_list()
catedra_name_initial_partial2=pc.fillna('').apply(lambda row: ud.unidecode((row['Primer nombre'].strip()+' '+row['Inicial segundo nombre'].strip()+' '+row['Segundo apellido'].strip()
                                ).strip().lower()),axis='columns').to_list()

# %%
catedra=pc.fillna('').apply(lambda row: ud.unidecode((row['Nombres'].strip()+' '+row['Primer apellido'].strip()+' '+row['Segundo apellido']
                                ).strip().lower()),axis='columns').to_list()

# %%
w=r[0]
JSON(w)

# %%
inst='I35961687'
for w in r:
    aus_inst=[]
    aus_ids=[]
    ids={}
    for d in w.get('authorships'):
        if d.get('institutions'):
            aus_inst=aus_inst+[d.get('author').get('display_name') for dd in d.get('institutions') if 
                      dd.get('id') and dd.get('id').split('/')[-1]==inst]
            aus_ids=aus_ids+[d.get('author').get('id') for dd in d.get('institutions') if 
                      dd.get('id') and dd.get('id').split('/')[-1]==inst]
            
    if aus_inst:
        aus_inst=[ud.unidecode(s.lower()).replace('-',' ').replace('.','') for s in aus_inst]
        
    ids=dict(zip(aus_inst,aus_ids))
        
    for au in aus_inst:
        #if au=='cristian a carvajal':
        #    raise Exception('ar')        
        if au in catedra: # Full names
            one=[au,100]
            w['institution_authorships']=aus_inst
            w['catedra_authorships']=one[0]
            w['catedra_id']=ids.get(au)
            break
        
        if au in catedra_initials: # Initial names and full last names
            one=[catedra[catedra_initials.index(au)],100]
            w['institution_authorships']=aus_inst
            w['catedra_authorships']=one[0]
            w['catedra_id']=ids.get(au)
            break
        
        if au in catedra_short: #First name and first last name
            one=[catedra[catedra_short.index(au)],100]
            w['institution_authorships']=aus_inst
            w['catedra_authorships']=one[0]
            w['catedra_id']=ids.get(au)
            break
        if au in catedra_name_initial: #First name - second initial and full last names
            one=[catedra[catedra_name_initial.index(au)],100]
            w['institution_authorships']=aus_inst
            w['catedra_authorships']=one[0]
            w['catedra_id']=ids.get(au)
            break
        if au in catedra_name_initial_partial: #First name - second initial and first last name
            one=[catedra[catedra_name_initial_partial.index(au)],100]
            w['institution_authorships']=aus_inst
            w['catedra_authorships']=one[0]
            w['catedra_id']=ids.get(au)
            break
        if au in catedra_name_initial_partial2: #First name - second initial and second last name
            one=[catedra[catedra_name_initial_partial2.index(au)],100]
            w['institution_authorships']=aus_inst
            w['catedra_authorships']=one[0]
            w['catedra_id']=ids.get(au)
            break

            
       
        one=process.extractOne(au,catedra)
        if one and set(au.split()).intersection(one[0].split()[-2:]) and au[0] in [s[0] for s in one[0].split()]:
            if len(au.split()[0])>1:
                if not set(au.split()).intersection(one[0].split()[:-2]):
                    one=[]
            if one and len(au.split())==4 and len(one[0].split())==4: #last names
                if au.split()[-2:]!=one[0].split()[-2:]:
                    one=[]
        else:
            one=[]
        #Quality check
        if one:
            if set([s[0] for s in au.split()]).difference([s[0] for s in one[0].split()]):
                one=[]
        
        w['institution_authorships']=aus_inst
        if one:
            w['catedra_authorships']=one[0]
            w['catedra_id']=ids.get(au)

        else:
            w['catedra_authorships']=''
            w['catedra_id']=''

        
    #if w['id']=='https://openalex.org/W2904803912':
    #    raise Exception('id')

# %%
df=pd.DataFrame(r)

# %%
df['Journal']=df.locations.apply(lambda L: [d.get('source') for d in L]).str[0].str.get('display_name')

# %%
df['concepts_0']=df['concepts'].apply(lambda L: [d.get('display_name') for d in L if d.get('level')==0])

# %%
pd.set_option('display.max_colwidth',500)

# %%
df.columns
# Out:
# Index(['id', 'doi', 'title', 'display_name', 'publication_year',
#        'publication_date', 'ids', 'language', 'primary_location', 'type',
#        'open_access', 'authorships', 'corresponding_author_ids',
#        'corresponding_institution_ids', 'apc_payment', 'cited_by_count',
#        'biblio', 'is_retracted', 'is_paratext', 'concepts', 'mesh',
#        'locations_count', 'locations', 'best_oa_location', 'grants',
#        'referenced_works', 'related_works', 'ngrams_url',
#        'abstract_inverted_index', 'cited_by_api_url', 'counts_by_year',
#        'updated_date', 'created_date', 'institution_authorships',
#        'catedra_authorships', 'catedra_id', 'Journal', 'concepts_0'],
#       dtype='object')

# %%
cdf=df[df['catedra_authorships'].apply(len)!=0][['title','Journal','doi','biblio','institution_authorships','publication_date', 
                                                 'catedra_authorships','catedra_id','concepts_0','cited_by_count']
                                           ].sort_values('catedra_authorships').reset_index(drop=True)
cdf=cdf[ (cdf.concepts_0.apply(lambda L: 'Physics' in L)) |
         (cdf.concepts_0.apply(lambda L: 'Computer science' in L)) |
         (cdf.concepts_0.apply(lambda L: 'Materials science' in L))
       ].reset_index(drop=True)

cdf=cdf[ ~(  
       (cdf.concepts_0.apply(lambda L: 'Medicine' in L)) |
       (cdf.concepts_0.apply(lambda L: 'Psychology' in L))
      )
       ].reset_index(drop=True)

# %%
cdf[:50]
# Out:
#                                                                                                                                                                                         title  \
# 0                                                                                                                                            Lepton dark matter portal in the inert Zee model
# 1                                                                                                                                  Type-II two-Higgs-doublet model in noncommutative geometry
# 2                                                                                                                                       Singlet-doublet Dirac dark matter and neutrino masses
# 3                                                                                                                                                 Inert doublet as multicomponent dark matter
# 4                                                                                                                        Phenomenological consistency of the singlet-triplet scotogenic model
# 5                                                                                                                                   Dirac dark matter, neutrino masses, and dark baryogenesis
# 6                                                                                                                         Quantum phase transition and Berry phase in an extended Dicke model
# 7                                                                                                                                          Fock-state superradiance in a cold atomic ensemble
# 8                                                                                                                               Orbital decay of short-period gas giants under evolving tides
# 9                                                                                                                               One-loop Dirac neutrino mass and mixed axion-WIMP dark matter
# 10                                                                                                                 Singlet fermion dark matter and Dirac neutrinos from Peccei-Quinn symmetry
# 11                                                                                Estimating the number of clear sky nights using GOES-16 images: a search for astronomical sites in Colombia
# 12                                                                                                   Experimental model for the description of the behaviour of a 9-mm projectile at a target
# 13                                                                                                                                       Weak pion-production and the second resonance region
# 14                                                                                                             Neutrino-induced single pion production and the reanalyzed bubble chamber data
# 15                            Tidal Coulomb Failure Stresses in the northern Andean intermediate depth seismic clusters: Implications for a possible correlation between tides and seismicity
# 16                                                                                               Correlation between tides and seismicity in Northwestern South America: The case of Colombia
# 17                                                                                                   Numerical Study on Surface Reconstruction and Roughness of Magnetorheological Elastomers
# 18                                                                                                      A time-energy delayed-choice interference experiment for the undergraduate laboratory
# 19                                             Theoretical study of electronic and optical properties in doped quantum structures with Razavy confining potential: effects of external fields
# 20            Electronic Transport Properties in GaAs/AlGaAs and InSe/InP Finite Superlattices under the Effect of a Non-Resonant Intense Laser Field and Considering Geometric Modifications
# 21                                                                                                  Study of Electronic and Transport Properties in Double-Barrier Resonant Tunneling Systems
# 22                                         Shallow Donor Impurity States with Excitonic Contribution in GaAs/AlGaAs and CdTe/CdSe Truncated Conical Quantum Dots under Applied Magnetic Field
# 23                                                                                                                   Self-Consistent Study of GaAs/AlGaAs Quantum Wells with Modulated Doping
# 24                                                          Self-Consistent Schrödinger-Poisson Study of Electronic Properties of GaAs Quantum Well Wires with Various Cross-Sectional Shapes
# 25                                                                                                                                            Focus-tunable experimental optical cryptosystem
# 26                                                   Correlation between structure and magnetic properties in Eu$${_{1 - x}}$$Ho$${_{x}}$$CrO$${_{3}}$$ (x = 0.0, 0.5 and 1.0) orthochromites
# 27                                                                       Experimental exploration of the vector nature of the dynamic order parameter near dynamic magnetic phase transitions
# 28  Integration of the straightforward and environmentally friendly sol–gel/solvothermal and photodeposition methods as a way to prepare highly photoactive Au/S-TiO2 and Cu/S-TiO2 materials
# 29                                             Experimental exploration of dynamic phase transitions and associated metamagnetic fluctuations for materials with different Curie temperatures
# 30                                                                                             A brief discussion of the magnetocaloric effect in thin films of manganite doped with chromium
# 31                                                                                                                                               Minimal radiative Dirac neutrino mass models
# 32                                                                                                                                   Dirac neutrino mass generation from a Majorana messenger
# 33                                                                                                       Phenomenology of the Zee model for Dirac neutrinos and general neutrino interactions
# 34                                                                                                       Hacia un modelo de medición de la ciencia desde el Sur Global: métricas responsables
# 35                                                                                                                         Anomaly-free Abelian gauge symmetries with Dirac scotogenic models
# 36                                                                                                                          Hysteresis characterization of an electrically focus-tunable lens
# 37                                                                                                                Optical characterization of electro-optics lenses for researching in optics
# 38                                         A novel process line for the valorization of industrial spent coffee grounds through coffee roasting technology and ultrasonic‐assisted extraction
# 39                                                                                             An Open edX Extension for Parallel Programming Assignments with Automatic Configurable Grading
# 40                                                                                                                    La paleomicrobiología molecular permite dilucidar el origen de la plaga
# 41                                                             Implementation of a portable EDXRF measurement chain for characterization of metallic objects of cultural interest in Colombia
# 42                                                                                                     Non-crossing monotone paths and binary trees in edge-ordered complete geometric graphs
# 43                                                                                                                          SUBSTRUCTURE FORMATION IN TIDAL STREAMS OF GALACTIC MINOR MERGERS
# 44                                                                                         Simulating the galactic system in interaction AM 2229-735 and the formation of its polar structure
# 45                                                                            Refractive index and group velocity of electromagnetic modes in a relativistic Fermi gas at finite temperatures
# 46                                                                                                  The impact of tidal friction evolution on the orbital decay of ultra-short-period planets
# 47                                                                                                             Ploonets: formation, evolution, and detectability of tidally detached exomoons
# 48                                                                                                                            Can we predict the impact conditions of metre-sized meteoroids?
# 49                                                                                                                                   Can close-in giant exoplanets preserve detectable moons?
#
#                                                                        Journal  \
# 0                                    International Journal of Modern Physics A
# 1                                                            Nuclear Physics B
# 2                                                              Physical review
# 3                                                            Nuclear Physics B
# 4                                               Journal of High Energy Physics
# 5                                                            Physical Review D
# 6                                                  European Physical Journal D
# 7                                                        Optics Communications
# 8                            Monthly Notices of the Royal Astronomical Society
# 9                                                              Physical review
# 10                                                             Physical review
# 11                                     International Journal of Remote Sensing
# 12                                                  Forensic sciences research
# 13                                                           Physical Review D
# 14                                                           Physical Review D
# 34                https://doi.org/10.24215/18539912e068
# 35          https://doi.org/10.1103/physrevd.103.095032
# 36             https://doi.org/10.1117/1.oe.59.4.044103
# 37                   https://doi.org/10.1117/12.2568577
# 38                    https://doi.org/10.1002/jctb.7259
# 39             https://doi.org/10.3991/ijep.v11i4.20097
# 40               https://doi.org/10.18257/raccefyn.1746
# 41      https://doi.org/10.1088/1742-6596/1247/1/012016
# 42           https://doi.org/10.1007/s10474-021-01166-2
# 43  https://doi.org/10.22201/ia.01851101p.2019.55.02.14
# 44                https://doi.org/10.1093/mnras/stz2943
# 45              https://doi.org/10.1364/josab.37.000211
# 46               https://doi.org/10.1093/mnras/stab1081
# 47                https://doi.org/10.1093/mnras/stz2110
# 48                https://doi.org/10.1093/mnrasl/slz060
# 49                https://doi.org/10.1093/mnras/stz3548
#
#                                                                               biblio  \
# 0             {'volume': None, 'issue': None, 'first_page': None, 'last_page': None}
# 1    {'volume': '983', 'issue': None, 'first_page': '115923', 'last_page': '115923'}
# 2             {'volume': '100', 'issue': '3', 'first_page': None, 'last_page': None}
# 3    {'volume': '962', 'issue': None, 'first_page': '115276', 'last_page': '115276'}
# 4            {'volume': '2020', 'issue': '4', 'first_page': None, 'last_page': None}
# 5             {'volume': '106', 'issue': '5', 'first_page': None, 'last_page': None}
# 6             {'volume': '74', 'issue': '10', 'first_page': None, 'last_page': None}
# 7             {'volume': None, 'issue': None, 'first_page': None, 'last_page': None}
# 8         {'volume': '486', 'issue': '3', 'first_page': '3963', 'last_page': '3974'}
# 9              {'volume': '99', 'issue': '7', 'first_page': None, 'last_page': None}
# 10            {'volume': '105', 'issue': '1', 'first_page': None, 'last_page': None}
# 11        {'volume': '41', 'issue': '14', 'first_page': '5103', 'last_page': '5126'}
# 12              {'volume': '6', 'issue': '1', 'first_page': '67', 'last_page': '74'}
# 13            {'volume': '105', 'issue': '3', 'first_page': None, 'last_page': None}
# 14            {'volume': '106', 'issue': '3', 'first_page': None, 'last_page': None}
# 15           {'volume': '762', 'issue': None, 'first_page': '61', 'last_page': '78'}
# 16          {'volume': '89', 'issue': None, 'first_page': '227', 'last_page': '245'}
# 17             {'volume': '11', 'issue': '3', 'first_page': '46', 'last_page': '46'}
# 18     {'volume': '40', 'issue': '5', 'first_page': '055401', 'last_page': '055401'}
# 19           {'volume': '21', 'issue': '2', 'first_page': '378', 'last_page': '395'}
# 20         {'volume': '23', 'issue': '9', 'first_page': '5169', 'last_page': '5169'}
# 21        {'volume': '12', 'issue': '10', 'first_page': '1714', 'last_page': '1714'}
# 22        {'volume': '11', 'issue': '11', 'first_page': '2832', 'last_page': '2832'}
# 23           {'volume': '13', 'issue': '5', 'first_page': '913', 'last_page': '913'}
# 24         {'volume': '11', 'issue': '5', 'first_page': '1219', 'last_page': '1219'}
# 25   {'volume': '148', 'issue': None, 'first_page': '107689', 'last_page': '107689'}
# 26            {'volume': None, 'issue': None, 'first_page': None, 'last_page': None}
# 27            {'volume': '102', 'issue': '9', 'first_page': None, 'last_page': None}
# 28            {'volume': '24', 'issue': '12', 'first_page': None, 'last_page': None}
# 29            {'volume': '102', 'issue': '2', 'first_page': None, 'last_page': None}
# 30            {'volume': None, 'issue': None, 'first_page': None, 'last_page': None}
# 31             {'volume': '99', 'issue': '7', 'first_page': None, 'last_page': None}
# 32            {'volume': '101', 'issue': '3', 'first_page': None, 'last_page': None}
# 33            {'volume': '104', 'issue': '1', 'first_page': None, 'last_page': None}
# 34          {'volume': '8', 'issue': '2', 'first_page': 'e068', 'last_page': 'e068'}
# 35            {'volume': '103', 'issue': '9', 'first_page': None, 'last_page': None}
# 36              {'volume': '59', 'issue': '04', 'first_page': '1', 'last_page': '1'}
# 37            {'volume': None, 'issue': None, 'first_page': None, 'last_page': None}
# 38           {'volume': '98', 'issue': '2', 'first_page': '451', 'last_page': '461'}
# 39               {'volume': '11', 'issue': '4', 'first_page': '7', 'last_page': '7'}
# 40         {'volume': '46', 'issue': '180', 'first_page': '815', 'last_page': '818'}
# 41  {'volume': '1247', 'issue': None, 'first_page': '012016', 'last_page': '012016'}
# 42            {'volume': '165', 'issue': '1', 'first_page': '28', 'last_page': '39'}
# 43            {'volume': None, 'issue': None, 'first_page': None, 'last_page': None}
# 44            {'volume': None, 'issue': None, 'first_page': None, 'last_page': None}
# 45           {'volume': '37', 'issue': '2', 'first_page': '211', 'last_page': '211'}
# 46            {'volume': None, 'issue': None, 'first_page': None, 'last_page': None}
# 47        {'volume': '489', 'issue': '2', 'first_page': '2313', 'last_page': '2322'}
# 48          {'volume': '486', 'issue': '1', 'first_page': 'L69', 'last_page': 'L73'}
# 49        {'volume': '492', 'issue': '3', 'first_page': '3499', 'last_page': '3508'}
#
#                                                                                                                                                                        institution_authorships  \
# 0                                                                                                                                          [alexandra gaviria, robinson longas, andres rivera]
# 1                                                                                                                                              [jimenez, fredy, diego restrepo, andres rivera]
# 2                                                                                                                                                              [diego restrepo, andres rivera]
# 3                                                                                                                                                                              [andres rivera]
# 4                                                                                                                                                              [diego restrepo, andres rivera]
# 5                                                                                                                                                              [diego restrepo, andres rivera]
# 6                                                                                                                                                   [camilo a estrada guerra, j mahecha gomez]
# 7                                                                                                                                                                           [camilo ae guerra]
# 8                                                                                                                                           [jaime a alvarado montes, carolina garcia carmona]
# 9                                                                                                                                                          [cristian a carvajal, oscar zapata]
# 10                                                                                                                       [cristian a carvajal, robinson longas, oscar rodriguez, oscar zapata]
# 11                                                                                               [d arbelaez cardona, e silva villa, j galvez, j alejandro martinez, pablo a cuartas restrepo]
# 12                                                                                 [patricia morales vega, diego alejandro jaramillo arango, jaime alberto osorio velez, david norena blandon]
# 13                                                                                                                                                  [d f tamayo agudelo, d e jaramillo arango]
# 14                                                                                                                                                  [d f tamayo agudelo, d e jaramillo arango]
# 15                                                                                                                                                         [gloria a moncayo, jorge i zuluaga]
# 16                                                                                                                                                         [gloria a moncayo, jorge i zuluaga]
# 17                                                                                                                                                              [johans restrepo, h d salinas]
# 18                                                                                                                                                      [jhonny castrillon, boris a rodriguez]
# 19                                                                                                                   [john a gil corrales, alvaro morales, vn tulupenko, ja vinasco, ca duque]
# 20                                                                                                                                             [john a gil corrales, alvaro morales, ca duque]
# 46  https://openalex.org/A2461273045
# 47  https://openalex.org/A2461273045
# 48  https://openalex.org/A2461273045
# 49  https://openalex.org/A2461273045
#
#                                                                                         concepts_0  \
# 0                                                               [Physics, Philosophy, Mathematics]
# 1                                         [Physics, Mathematics, Philosophy, Engineering, History]
# 2                                                                            [Physics, Philosophy]
# 3                                                                           [Physics, Mathematics]
# 4                                                                  [Physics, Mathematics, History]
# 5                                                                               [Physics, History]
# 6                                                                               [Physics, Biology]
# 7                                                                                        [Physics]
# 8                                                                     [Physics, Political science]
# 9                                                                                        [Physics]
# 10                                                                              [Physics, History]
# 11                                   [Geography, Environmental science, Computer science, Physics]
# 12                                                                              [Physics, Geology]
# 13                                                                     [Physics, Art, Engineering]
# 14                                                                                       [Physics]
# 15                                                                              [Geology, Physics]
# 16                                                                              [Geology, Physics]
# 17                            [Materials science, Computer science, Physics, Mathematics, Geology]
# 18                                                                          [Physics, Engineering]
# 19                                                                                       [Physics]
# 20                                                         [Materials science, Chemistry, Physics]
# 21                                                               [Materials science, Physics, Art]
# 22                                                                          [Physics, Mathematics]
# 23                                                                    [Materials science, Physics]
# 24                                           [Physics, Mathematics, Computer science, Engineering]
# 25                                                                     [Computer science, Physics]
# 26                                                         [Materials science, Chemistry, Physics]
# 27                                                                            [Physics, Economics]
# 28                                   [Materials science, Chemistry, Physics, Engineering, Biology]
# 29                                                                    [Materials science, Physics]
# 30                                                                    [Materials science, Physics]
# 31                                                                          [Physics, Mathematics]
# 32                                                                                       [Physics]
# 33                                                                  [Physics, Philosophy, History]
# 34  [Political science, Sociology, Computer science, Philosophy, Geography, Business, Mathematics]
# 35                                                                              [Physics, History]
# 36                                                  [Computer science, Materials science, Physics]
# 37                                                [Computer science, Physics, Philosophy, Biology]
# 38                                   [Engineering, Chemistry, Computer science, Materials science]
# 39                                                                 [Computer science, Engineering]
# 40                                                                                  [Physics, Art]
# 41       [Computer science, Materials science, Physics, Chemistry, Environmental science, History]
# 42                                                        [Mathematics, Physics, Computer science]
# 43                                                        [Physics, Computer science, Engineering]
# 44                                                                                       [Physics]
# 45                                                                          [Physics, Engineering]
# 46                                                                                       [Physics]
# 47                                                                                       [Physics]
# 48                                     [Environmental science, Computer science, Physics, Geology]
# 49                                                                    [Physics, Political science]
#
#     cited_by_count
# 0                0
# 1                0
# 2               16
# 3                9
# 4                7
# 5                0
# 6                2
# 7                1
# 8                7
# 9               19
# 10               3
# 11               0
# 12               0
# 13               1
# 14               0
# 15               1
# 16               4
# 17               0
# 18               5
# 19               4
# 20               0
# 21               0
# 22               6
# 23               0
# 24               5
# 25               2
# 26               0
# 27               8
# 28               0
# 29              16
# 30               0
# 31              31
# 32              12
# 33               3
# 34               2
# 35               7
# 36               4
# 37               1
# 38               0
# 39               0
# 40               0
# 41               0
# 42               1
# 43               0
# 44               0
# 45               1
# 46               5
# 47              17
# 48               2
# 49               9

# %%
.to_excel('publicaciones_catedra.xlsx',index=False)

# %%
au=aus_inst[1]

# %%
#intersection last names
# Out:
# ('marllory isaza ruiz', 86)

# %%
#intersection first name
au[0] in [s[0] for s in one[0].split()]
# Out:
# 'm'
